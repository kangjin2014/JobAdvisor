# %% [markdown]
# # parse resume and create features

# %%
import ast
import pandas as pd

# %%
df = pd.read_csv('/users/kangjin/desktop/resume_ds.csv')
df.head()
# Out:
#                                           Unnamed: 0  \
# 0  {0: [u'Counsellor', u'Private Practice', 1, u'...
# 1  {0: [u'CONSULTANT AML Model Management', u'BMO...
# 2  {0: [u'Product Manager', u'Uken Games', 'less ...
# 3  {0: [u'Business Intelligence Consultant', u'Vi...
# 4  {0: [u'Advanced Analytics Manager/Strategist',...
#
#                                                 0 Unnamed: 2 Unnamed: 3  \
# 0  https://www.indeed.com/r/5f62ce761db226a5?sp=0        NaN        NaN
# 1  https://www.indeed.com/r/d4081447e8a96885?sp=0        NaN        NaN
# 2  https://www.indeed.com/r/b99003866721dc36?sp=0        NaN        NaN
# 3  https://www.indeed.com/r/4c2696b12fc9d6a6?sp=0        NaN        NaN
# 4  https://www.indeed.com/r/9fb8af796c5cdbd2?sp=0        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df['Unnamed: 0'][0]
# Out:
# '{0: [u\'Counsellor\', u\'Private Practice\', 1, u\'\\u2022 Receive client phone calls and conduct intake \\u2022 Compile and edit necessary documents for private practice including informed consent, request for services, receipts, etc. \\xa0\\u2022 Prepare case histories and assess client problems\\xa0\\u2022 Promote services and build client base \\xa0\\u2022 Work with clients to determine and achieve goals of counselling through psychotherapy\'], 1: [u\'Youth Coordinator\', u"Good Shepherd Parish & Saint George\'s Parish", 8, u"\\u2022 Work directly with youth ages 5 - 17, creating and implementing the parish youth program, including youth groups, retreats, and music ministry for grades 6 through 12.\\xa0\\u2022 Plan and coordinate liturgies including music, passion plays, adoration, and liturgy of the word for reconciliation.\\xa0\\u2022 Facilitate opportunities for adults\' spiritual growth including parent faith-nights and retreats for ministry volunteers; oversee spiritual and
# ...

# %%
df['Unnamed: 0'][0]
# Out:
# '{0: [u\'Counsellor\', u\'Private Practice\', 1, u\'\\u2022 Receive client phone calls and conduct intake \\u2022 Compile and edit necessary documents for private practice including informed consent, request for services, receipts, etc. \\xa0\\u2022 Prepare case histories and assess client problems\\xa0\\u2022 Promote services and build client base \\xa0\\u2022 Work with clients to determine and achieve goals of counselling through psychotherapy\'], 1: [u\'Youth Coordinator\', u"Good Shepherd Parish & Saint George\'s Parish", 8, u"\\u2022 Work directly with youth ages 5 - 17, creating and implementing the parish youth program, including youth groups, retreats, and music ministry for grades 6 through 12.\\xa0\\u2022 Plan and coordinate liturgies including music, passion plays, adoration, and liturgy of the word for reconciliation.\\xa0\\u2022 Facilitate opportunities for adults\' spiritual growth including parent faith-nights and retreats for ministry volunteers; oversee spiritual and
# ...

# %%
def create_new_column(a):
    
    # very useful
    
    try:
        d = ast.literal_eval(a)
    except:
        d = {}
    
    try:
        job_0 = d[0]
    except:
        job_0 = 'Null'
    try:
        job_1 = d[1]
    except:
        job_1 = 'Null'
    try:
        job_2 = d[2]
    except:
        job_2 = 'Null'
    try:
        job_3 = d[3]
    except:
        job_3 = 'Null'
        
    return job_0,job_1,job_2,job_3

# %%
df_new = df[df['Unnamed: 0'] != '{}']['Unnamed: 0'].reset_index(drop=True)
df_new = df_new.apply(create_new_column).tolist()
df_new = pd.DataFrame(df_new, columns = ['job0','job1','job2','job3'])
# Out:
#                                                   job0  \
# 0    [Counsellor, Private Practice, 1, • Receive cl...
# 1    [CONSULTANT AML Model Management, BMO, less th...
# 2    [Product Manager, Uken Games, less than 1 year...
# 3    [Business Intelligence Consultant, Visier Solu...
# 4    [Advanced Analytics Manager/Strategist, IBM Ca...
# 5    [Data Scientist/Analyst, TD INSURANCE MELOCHE ...
# 6    [Project Manager, Scotiabank, less than 1 year...
# 7    [GEOPHYSICAL DATA PROCESSOR, Geo Data Solution...
# 8    [Big data Tools Course designer/ part time pro...
# 9    [CTO and Data Scientist, KapowKidz Co, 2, • Le...
# 10   [Machine Learning / Data Scientist, Cortechma ...
# 11   [Senior Forensic Analyst (Senior Data Scientis...
# 12   [IT Consultant and Data Scientist, Tri City Gr...
# 13   [SENIOR DATA SCIENTIST IN RESEARCH AND DEVELOP...
# 14   [CTO and Data Scientist, NeuroBlot Inc., 2, * ...
# 15   [Data Scientist, Scopemedia Inc, 1, 1, Image C...
# ...

# %%
df_new.head()
# Out:
#                                                 job0  \
# 0  [Counsellor, Private Practice, 1, • Receive cl...
# 1  [CONSULTANT AML Model Management, BMO, less th...
# 2  [Product Manager, Uken Games, less than 1 year...
# 3  [Business Intelligence Consultant, Visier Solu...
# 4  [Advanced Analytics Manager/Strategist, IBM Ca...
#
#                                                 job1  \
# 0  [Youth Coordinator, Good Shepherd Parish & Sai...
# 1  [SENIOR DATA SCIENTIST Advanced Analytics, Pre...
# 2  [Business Analyst/BI Consultant (Contract), DX...
# 3  [Data Scientist, jSonar, less than 1 year, As ...
# 4  [Predictive Sciences Consultant, Equifax Canad...
#
#                                                 job2  \
# 0  [Counsellor, No Company, less than 1 year, • R...
# 1  [SENIOR STATISTICAL ANALYST, Precima, Inc, 1, ...
# 2  [Reporting Tools Automation Development and Op...
# 3  [Data Science / Data Architecture Consultant, ...
# ...

# %%
def job_n_features(job_element):
    job_title = job_element[0]
    job_company = job_element[1]
    job_year = job_element[2]
    job_des = job_element[3]
    return job_title, job_company, job_year, job_des

# %%
df_job_0=pd.DataFrame(df_new['job0'].apply(job_n_features).tolist(), \
             columns = ['job_0_title', 'job_0_company', 'job_0_year', 'job_0_des'])

# %%
df_job_1=pd.DataFrame(df_new['job1'].apply(job_n_features).tolist(), \
             columns = ['job_1_title', 'job_1_company', 'job_1_year', 'job_1_des'])

# %%
df_job_2=pd.DataFrame(df_new['job2'].apply(job_n_features).tolist(), \
             columns = ['job_2_title', 'job_2_company', 'job_2_year', 'job_2_des'])

# %%
df_job_3=pd.DataFrame(df_new['job3'].apply(job_n_features).tolist(), \
             columns = ['job_3_title', 'job_3_company', 'job_3_year', 'job_3_des'])

# %%
df_all = pd.concat([df_job_0,df_job_1,df_job_2,df_job_3], axis=1)

# %%
df_all.head()
# Out:
#                              job_0_title     job_0_company        job_0_year  \
# 0                             Counsellor  Private Practice                 1
# 1        CONSULTANT AML Model Management               BMO  less than 1 year
# 2                        Product Manager        Uken Games  less than 1 year
# 3       Business Intelligence Consultant  Visier Solutions  less than 1 year
# 4  Advanced Analytics Manager/Strategist        IBM Canada                 7
#
#                                            job_0_des  \
# 0  • Receive client phone calls and conduct intak...
# 1  Develop, Design, Tune and improve existing/new...
# 2  -Feature ownership- Designed features, created...
# 3  I was a customer-facing technical resource for...
# 4  • Work with business leaders identify areas of...
#
#                                  job_1_title  \
# 0                          Youth Coordinator
# 1   SENIOR DATA SCIENTIST Advanced Analytics
# ...
