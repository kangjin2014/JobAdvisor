# %%
from es_application import elasticsearch_func as ef

# %%
res = ef.es_match('data scientist', 'python')

# %%
type(res)
# Out:
# list

# %%
res
# Out:
# [{'company': 'Zenith System Solutions',
# ...
